# %%
#pip install fastcluster

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("E:\\Trainings\\Complete Data Science Bootcamp - Udemy\\Cluster Analysis\\K-Means Clustering\\Example 5 - Heatmaps and Dendrograms\\Country clusters standardized.csv", index_col='Country')

# %%
data
# Out:
#            Latitude  Longitude  Language
# Country
# USA        0.186540  -1.089160         0
# Canada     0.728588  -1.008604         0
# France     0.241895   0.137900         1
# UK         0.467671   0.080922         0
# Germany    0.378729   0.230360         2
# Australia -2.003422   1.648581         0

# %%
data.shape
# Out:
# (6, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, USA to Australia
# Data columns (total 3 columns):
# Latitude     6 non-null float64
# Longitude    6 non-null float64
# Language     6 non-null int64
# dtypes: float64(2), int64(1)
# memory usage: 192.0+ bytes

# %%
data.describe()
# Out:
#            Latitude     Longitude  Language
# count  6.000000e+00  6.000000e+00   6.00000
# mean   1.666666e-10  1.666666e-10   0.50000
# std    1.000000e+00  1.000000e+00   0.83666
# min   -2.003422e+00 -1.089160e+00   0.00000
# 25%    2.003785e-01 -7.362224e-01   0.00000
# 50%    3.103119e-01  1.094110e-01   0.00000
# 75%    4.454352e-01  2.072452e-01   0.75000
# max    7.285877e-01  1.648581e+00   2.00000

# %%
x_scaled = data.copy()
x_scaled = x_scaled.drop(['Language'], axis=1)
#x_scaled['Country'] = x_scaled['Country'].map({'USA':0, 'Canada':1, 'France':2, 'UK':3, 'Germany':4, 'Australia':5})
x_scaled
# Out:
#            Latitude  Longitude
# Country
# USA        0.186540  -1.089160
# Canada     0.728588  -1.008604
# France     0.241895   0.137900
# UK         0.467671   0.080922
# Germany    0.378729   0.230360
# Australia -2.003422   1.648581

# %%
sns.clustermap(x_scaled, cmap="mako")
