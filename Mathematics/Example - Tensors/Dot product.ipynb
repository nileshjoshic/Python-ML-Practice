# %% [markdown]
# ## Import relevant libraries

# %%
import numpy as np

# %% [markdown]
# ## Dot product

# %%
x = np.array([2,8,-4])
y = np.array([1,-7,3])

# %%
# 2*1 + 8*(-7) + (-4)*3
np.dot(x,y)
# Out:
# -66

# %%
u = np.array([0,2,5,8])
v = np.array([20,3,4,-1])

# %%
np.dot(u,v)
# Out:
# 18

# %% [markdown]
# ## Scalar * Scalar

# %%
np.dot(5,6)
# Out:
# 30

# %%
np.dot(10,-2)
# Out:
# -20

# %% [markdown]
# ## Scalar * Vector

# %%
x
# Out:
# array([ 2,  8, -4])

# %%
5*x
# Out:
# array([ 10,  40, -20])
