# %%
import numpy as np

# %%
s = 5

# %%
v = np.array([3,4,5])

# %%
m = np.array([[3,5,5],[6,7,8]])

# %%
s
# Out:
# 5

# %%
v
# Out:
# array([3, 4, 5])

# %%
m
# Out:
# array([[3, 5, 5],
#        [6, 7, 8]])

# %%
type(s)
# Out:
# int

# %%
type(v)
# Out:
# numpy.ndarray

# %%
type(m)
# Out:
# numpy.ndarray

# %%
s_array = np.array(5)

# %%
s_array
# Out:
# array(5)

# %%
type(s_array)
# Out:
# numpy.ndarray

# %%
v.shape
# Out:
# (3,)

# %%
m.shape
# Out:
# (2, 3)

# %%
s_array.shape
# Out:
# ()

# %%
v.reshape(1,3)
# Out:
# array([[3, 4, 5]])

# %%
v.reshape(3,1)
# Out:
# array([[3],
#        [4],
#        [5]])

# %%
m+s
# Out:
# array([[ 8, 10, 10],
#        [11, 12, 13]])

# %%
m+s_array
# Out:
# array([[ 8, 10, 10],
#        [11, 12, 13]])

# %%
v
# Out:
# array([3, 4, 5])

# %%
s
# Out:
# 5

# %%
v+s
# Out:
# array([ 8,  9, 10])

# %%
v+s_array
# Out:
# array([ 8,  9, 10])

# %%
m
# Out:
# array([[3, 5, 5],
#        [6, 7, 8]])

# %%
v
# Out:
# array([3, 4, 5])

# %%
m+v
# Out:
# array([[ 6,  9, 10],
#        [ 9, 11, 13]])
